# %% [markdown]
# # iTransformer Stock Prediction Test
# This notebook demonstrates the training and testing of the iTransformer model for stock prediction.

# %% [markdown]
# ## Imports and Setup

# %%
import torch
import numpy as np
import json
import os
from IPython.display import display
import matplotlib.pyplot as plt

from configs import StockPredictionConfig
from exp_stock_forecasting import Exp_Stock_Forecast
from utils.loss import get_loss_function
from utils.visualization import StockVisualizer

# %% [markdown]
# ## Configuration

# %%
def setup_config():
    config = StockPredictionConfig()
    
    # Model configuration
    config.seq_len = 60      # 1 hour of minute-by-minute data
    config.pred_len = 60     # Predict next hour
    config.label_len = 60    # Set label length to match sequence length
    config.train_epochs = 5  # Number of training epochs
    config.batch_size = 32   # Batch size
    config.d_model = 256     # Model dimension
    config.n_heads = 16      # Number of attention heads
    config.e_layers = 4      # Number of encoder layers
    config.dropout = 0.2     # Dropout rate
    config.test_size = 1     # Number of test files
    
    # Loss configuration
    config.loss_type = "directional"
    config.loss_kwargs = {
        "base_loss": "squared_mae",
        "direction_weight": 0.3
    }
    
    # Device configuration
    if torch.cuda.is_available():
        config.use_gpu = True
        print("Using CUDA GPU")
    elif torch.backends.mps.is_available():
        config.use_gpu = True
        print("Using Apple Silicon MPS")
    else:
        config.use_gpu = False
        print("Using CPU")
    
    return config

# %% [markdown]
# ## Model Training and Visualization

# %%
def save_embeddings(embeddings, file_path):
    """Save embeddings to a JSON file"""
    embeddings_dict = {
        'shape': list(embeddings.shape),
        'data': embeddings.cpu().numpy().tolist()
    }
    
    with open(file_path, 'w') as f:
        json.dump(embeddings_dict, f, indent=2)
    print(f"Embeddings saved to {file_path}")

# %%
def train_and_visualize():
    # Setup
    config = setup_config()
    exp = Exp_Stock_Forecast(config)
    setting = 'jupyter_test_stock_prediction'
    visualizer = StockVisualizer()
    
    try:
        print("Starting training...")
        print(f"Using {config.seq_len} minutes of data to predict next {config.pred_len} minutes")
        
        # Get first batch for embeddings
        train_data, train_loader = exp._get_data(flag='train')
        batch_x, batch_x_mark, batch_y, batch_y_mark = next(iter(train_loader))
        
        # Get embeddings
        batch_x = batch_x.float().to(exp.device)
        batch_x_mark = batch_x_mark.float().to(exp.device)
        
        with torch.no_grad():
            embeddings = exp.model.get_embeddings(batch_x[0:1], batch_x_mark[0:1])
            os.makedirs(config.embeddings_dir, exist_ok=True)
            save_embeddings(embeddings, os.path.join(config.embeddings_dir, 'aapl_embeddings.json'))
        
        # Train model
        model = exp.train(setting)
        
        # Display training metrics plot
        plt.figure(figsize=(12, 6))
        img = plt.imread('./figures/training_metrics.png')
        plt.imshow(img)
        plt.axis('off')
        plt.title('Training Metrics')
        plt.show()
        
        # Display learning rate plot
        plt.figure(figsize=(10, 4))
        img = plt.imread('./figures/learning_rate.png')
        plt.imshow(img)
        plt.axis('off')
        plt.title('Learning Rate Schedule')
        plt.show()
        
        print("\nRunning test prediction...")
        exp.test(setting, test=1)
        
        # Display prediction plots
        plt.figure(figsize=(15, 10))
        img = plt.imread('./figures/all_stocks_predictions_close.png')
        plt.imshow(img)
        plt.axis('off')
        plt.title('Stock Price Predictions')
        plt.show()
        
        print("\nTest completed successfully!")
        
    except Exception as e:
        print(f"Error during test: {str(e)}")
        raise e

# %% [markdown]
# ## Run the Test

# %%
if __name__ == "__main__":
    train_and_visualize()
# Out:
# Using 5 files for training (limited by train_size=5)
# Data split - Train: 5 files, Validation: 2 files, Test: 1 files
#
# Debug - Ticker column info:
# Ticker value counts:
# ticker
# NVDA    960
# DJT     957
# ELAB    956
# SOXL    953
# GSAT    943
# Name: count, dtype: int64
# Ticker dtype: object
#
# Using all available stocks: ['A', 'AA', 'AAA', 'AAAU', 'AACG', 'AACT', 'AACT.WS', 'AADI', 'AADR', 'AAL', 'AAM', 'AAM.U', 'AAM.WS', 'AAME', 'AAOI', 'AAON', 'AAP', 'AAPB', 'AAPD', 'AAPL', 'AAPR', 'AAPU', 'AAPX', 'AAPY', 'AAT', 'AAXJ', 'AB', 'ABAT', 'ABBV', 'ABCB', 'ABCL', 'ABCS', 'ABEO', 'ABEQ', 'ABEV', 'ABG', 'ABL', 'ABLLL', 'ABLLW', 'ABLV', 'ABM', 'ABNB', 'ABNY', 'ABOS', 'ABR', 'ABRpD', 'ABRpE', 'ABRpF', 'ABSI', 'ABT', 'ABTS', 'ABUS', 'ABVC', 'ABVE', 'ABVEW', 'ABVX', 'AC', 'ACA', 'ACAB', 'ACAD', 'ACB', 'ACCD', 'ACCO', 'ACDC', 'ACEL', 'ACES', 'ACET', 'ACGL', 'ACGLN', 'ACGLO', 'ACHC', 'ACHL', 'ACHR', 'ACHR.WS', 'ACHV', 'ACI', 'ACIC', 'ACIO', 'ACIU', 'ACIW', 'ACLS', 'ACLX', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACNT', 'ACON', 'ACONW', 'ACP', 'ACPpA', 'ACR', 'ACRE', 'ACRS', 'ACRV', 'ACRpC', 'ACRpD', 'ACT', 'ACTG', 'ACTU', 'ACTV', 'ACU', 'ACV', 'ACVA', 'ACVF', 'ACWI', 'ACWV', 'ACWX', 'ACXP', 'ADAG', 'ADAP', 'ADBE', 'ADC', 'ADCT', 'ADCpA', 'ADD', 'ADEA', 'ADFI', 'ADGM', 'ADI', 'ADIL', 'ADIV', 'ADM', 'ADMA', 'ADME', 'ADN', 'ADNT', 'ADNWW', 'ADP', 'ADPT', 'ADPV', 'ADSE', 'ADSEW', 'ADSK', 'ADT', 'ADTN', 'ADTX', 'ADUS', 'ADV', 'ADVM', 'ADVWW', 'ADX', 'ADXN', 'AE', 'AEAE', 'AEE', 'AEF', 'AEFC', 'AEG', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEM', 'AEMD', 'AENT', 'AENTW', 'AEO', 'AEON', 'AEP', 'AER', 'AERT', 'AES', 'AESI', 'AESR', 'AETH', 'AEVA', 'AEVA.WS', 'AEYE', 'AFB', 'AFBI', 'AFCG', 'AFG', 'AFGB', 'AFGC', 'AFGD', 'AFGE', 'AFIF', 'AFJK', 'AFJKR', 'AFK', 'AFL', 'AFLG', 'AFMC', 'AFMD', 'AFRI', 'AFRIW', 'AFRM', 'AFSM', 'AFYA', 'AG', 'AGAE', 'AGCO', 'AGD', 'AGEN', 'AGFY', 'AGG', 'AGGH', 'AGGS', 'AGGY', 'AGI', 'AGIO', 'AGIX', 'AGL', 'AGM', 'AGMH', 'AGMpD', 'AGMpE', 'AGMpF', 'AGMpG', 'AGNC', 'AGNCL', 'AGNCM', 'AGNCN', 'AGNCO', 'AGNCP', 'AGNG', 'AGO', 'AGOX', 'AGQ', 'AGQI', 'AGR', 'AGRI', 'AGRO', 'AGS', 'AGX', 'AGYS', 'AGZ', 'AGZD', 'AHCO', 'AHG', 'AHH', 'AHHpA', 'AHLT', 'AHLpC', 'AHLpD', 'AHLpE', 'AHOY', 'AHR', 'AHT', 'AHTpD', 'AHTpF', 'AHYB', 'AI', 'AIA', 'AIBD', 'AIBU', 'AIEQ', 'AIEV', 'AIFD', 'AIFF', 'AIFU', 'AIG', 'AIHS', 'AILE', 'AILEW', 'AIM', 'AIMAW', 'AIMD', 'AIN', 'AIO', 'AIOT', 'AIP', 'AIPI', 'AIQ', 'AIR', 'AIRE', 'AIRG', 'AIRI', 'AIRJ', 'AIRL', 'AIRR', 'AIRS', 'AIRT', 'AIRTP', 'AISP', 'AISPW', 'AIT', 'AITR', 'AITRR', 'AITRU', 'AIV', 'AIVC', 'AIVL', 'AIXI', 'AIYY', 'AIZ', 'AIZN', 'AJAN', 'AJG', 'AJUL', 'AJX', 'AKA', 'AKAM', 'AKAN', 'AKBA', 'AKO.A', 'AKO.B', 'AKR', 'AKRO', 'AKTS', 'AKTX', 'AKYA', 'AL', 'ALAB', 'ALAI', 'ALAR', 'ALB', 'ALBT', 'ALBpA', 'ALC', 'ALCE', 'ALCO', 'ALCYW', 'ALDFU', 'ALDX', 'ALE', 'ALEC', 'ALEX', 'ALF', 'ALFUW', 'ALG', 'ALGM', 'ALGN', 'ALGS', 'ALGT', 'ALHC', 'ALIT', 'ALK', 'ALKS', 'ALKT', 'ALL', 'ALLE', 'ALLK', 'ALLO', 'ALLR', 'ALLT', 'ALLY', 'ALLpB', 'ALLpH', 'ALLpI', 'ALLpJ', 'ALMS', 'ALNT', 'ALNY', 'ALOT', 'ALRM', 'ALRN', 'ALRS', 'ALSAW', 'ALSN', 'ALT', 'ALTG', 'ALTGpA', 'ALTI', 'ALTL', 'ALTM', 'ALTO', 'ALTR', 'ALTS', 'ALTY', 'ALUR', 'ALUR.WS', 'ALV', 'ALVO', 'ALVOW', 'ALVR', 'ALX', 'ALXO', 'ALZN', 'AM', 'AMAL', 'AMAT', 'AMAX', 'AMBA', 'AMBC', 'AMBI', 'AMBI.WS', 'AMBO', 'AMBP', 'AMBP.WS', 'AMC', 'AMCR', 'AMCX', 'AMD', 'AMDL', 'AMDS', 'AMDY', 'AME', 'AMED', 'AMG', 'AMGN', 'AMH', 'AMHpG', 'AMHpH', 'AMID', 'AMIX', 'AMJB', 'AMKR', 'AMLI', 'AMLP', 'AMLX', 'AMN', 'AMNA', 'AMOM', 'AMP', 'AMPG', 'AMPH', 'AMPL', 'AMPS', 'AMPX', 'AMPX.WS', 'AMPY', 'AMR', 'AMRC', 'AMRK', 'AMRN', 'AMRX', 'AMS', 'AMSC', 'AMSF', 'AMST', 'AMT', 'AMTB', 'AMTD', 'AMTM', 'AMTX', 'AMWD', 'AMWL', 'AMX', 'AMZA', 'AMZD', 'AMZN', 'AMZP', 'AMZU', 'AMZY', 'AMZZ', 'AN', 'ANAB', 'ANDE', 'ANEB', 'ANET', 'ANF', 'ANGH', 'ANGI', 'ANGL', 'ANGO', 'ANGpA', 'ANGpB', 'ANIK', 'ANIP', 'ANIX', 'ANL', 'ANNX', 'ANRO', 'ANSC', 'ANSCW', 'ANSS', 'ANTE', 'ANTX', 'ANVS', 'ANY', 'AOA', 'AOCT', 'AOD', 'AOHY', 'AOK', 'AOM', 'AOMN', 'AOMR', 'AON', 'AOR', 'AORT', 'AOS', 'AOSL', 'AOUT', 'AP', 'APA', 'APAM', 'APCB', 'APCX', 'APD', 'APDN', 'APEI', 'APG', 'APGE', 'APH', 'API', 'APIE', 'APLD', 'APLE', 'APLM', 'APLMW', 'APLS', 'APLT', 'APLY', 'APM', 'APMU', 'APO', 'APOC', 'APOG', 'APOS', 'APO ...
# Apple Silicon MPS available
# Using Apple Silicon MPS
# Use MPS: mps
# Using 5 files for training (limited by train_size=5)
# Data split - Train: 5 files, Validation: 2 files, Test: 1 files
#
# Debug - Ticker column info:
# Ticker value counts:
# ticker
# RGTI    960
# SOUN    960
# TSLL    956
# NVDA    954
# BBAI    953
# Name: count, dtype: int64
# Ticker dtype: object
#
# Using all available stocks: ['A', 'AA', 'AAA', 'AAAU', 'AACG', 'AACT', 'AACT.WS', 'AADI', 'AADR', 'AAL', 'AAM', 'AAM.U', 'AAM.WS', 'AAME', 'AAOI', 'AAON', 'AAP', 'AAPB', 'AAPD', 'AAPL', 'AAPR', 'AAPU', 'AAPX', 'AAPY', 'AAT', 'AAXJ', 'AB', 'ABAT', 'ABBV', 'ABCB', 'ABCL', 'ABCS', 'ABEO', 'ABEQ', 'ABEV', 'ABG', 'ABL', 'ABLLL', 'ABLLW', 'ABLV', 'ABM', 'ABNB', 'ABNY', 'ABOS', 'ABP', 'ABR', 'ABRpD', 'ABRpE', 'ABRpF', 'ABSI', 'ABT', 'ABTS', 'ABUS', 'ABVC', 'ABVE', 'ABVEW', 'ABVX', 'AC', 'ACA', 'ACAD', 'ACB', 'ACCD', 'ACCO', 'ACDC', 'ACEL', 'ACES', 'ACET', 'ACGL', 'ACGLN', 'ACGLO', 'ACHC', 'ACHL', 'ACHR', 'ACHR.WS', 'ACHV', 'ACI', 'ACIC', 'ACIO', 'ACIU', 'ACIW', 'ACLO', 'ACLS', 'ACLX', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACNT', 'ACOG', 'ACON', 'ACP', 'ACPpA', 'ACR', 'ACRE', 'ACRS', 'ACRV', 'ACRpC', 'ACRpD', 'ACT', 'ACTG', 'ACTU', 'ACTV', 'ACU', 'ACV', 'ACVA', 'ACVF', 'ACWI', 'ACWV', 'ACWX', 'ACXP', 'ADAG', 'ADAP', 'ADBE', 'ADC', 'ADCT', 'ADCpA', 'ADD', 'ADEA', 'ADFI', 'ADGM', 'ADI', 'ADIL', 'ADM', 'ADMA', 'ADME', 'ADN', 'ADNT', 'ADNWW', 'ADP', 'ADPT', 'ADPV', 'ADSE', 'ADSEW', 'ADSK', 'ADT', 'ADTN', 'ADTX', 'ADUR', 'ADUS', 'ADV', 'ADVE', 'ADVM', 'ADVWW', 'ADX', 'ADXN', 'AE', 'AEE', 'AEF', 'AEFC', 'AEG', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEM', 'AEMD', 'AENT', 'AENTW', 'AEO', 'AEON', 'AEP', 'AER', 'AERT', 'AES', 'AESI', 'AESR', 'AETH', 'AEVA', 'AEVA.WS', 'AEYE', 'AFB', 'AFBI', 'AFCG', 'AFG', 'AFGB', 'AFGC', 'AFGD', 'AFGE', 'AFIF', 'AFIX', 'AFJK', 'AFK', 'AFL', 'AFLG', 'AFMC', 'AFMD', 'AFRI', 'AFRIW', 'AFRM', 'AFSM', 'AFYA', 'AG', 'AGAE', 'AGCO', 'AGD', 'AGEN', 'AGFY', 'AGG', 'AGGH', 'AGGY', 'AGI', 'AGIO', 'AGIX', 'AGL', 'AGM', 'AGM.A', 'AGMH', 'AGMpD', 'AGMpE', 'AGMpF', 'AGMpG', 'AGNC', 'AGNCL', 'AGNCM', 'AGNCN', 'AGNCO', 'AGNCP', 'AGNG', 'AGO', 'AGOX', 'AGQ', 'AGQI', 'AGR', 'AGRH', 'AGRI', 'AGRO', 'AGS', 'AGX', 'AGYS', 'AGZ', 'AGZD', 'AHCO', 'AHG', 'AHH', 'AHHpA', 'AHLT', 'AHLpC', 'AHLpD', 'AHLpE', 'AHLpF', 'AHOY', 'AHR', 'AHT', 'AHTpD', 'AHTpF', 'AHTpG', 'AHTpH', 'AHTpI', 'AHYB', 'AI', 'AIA', 'AIBD', 'AIBU', 'AIEQ', 'AIEV', 'AIFD', 'AIFF', 'AIFU', 'AIG', 'AIHS', 'AILE', 'AILEW', 'AIM', 'AIMAW', 'AIMBU', 'AIMD', 'AIN', 'AINP', 'AIO', 'AIOT', 'AIP', 'AIPI', 'AIQ', 'AIR', 'AIRE', 'AIRG', 'AIRI', 'AIRJ', 'AIRJW', 'AIRL', 'AIRR', 'AIRS', 'AIRT', 'AIRTP', 'AIS', 'AISP', 'AISPW', 'AIT', 'AITRR', 'AIV', 'AIVC', 'AIVI', 'AIVL', 'AIXI', 'AIYY', 'AIZ', 'AIZN', 'AJAN', 'AJG', 'AJUL', 'AKA', 'AKAM', 'AKAN', 'AKBA', 'AKO.B', 'AKR', 'AKRO', 'AKTS', 'AKTX', 'AKYA', 'AL', 'ALAB', 'ALAI', 'ALAR', 'ALB', 'ALBT', 'ALBpA', 'ALC', 'ALCE', 'ALCO', 'ALCY', 'ALDFU', 'ALDX', 'ALE', 'ALEC', 'ALEX', 'ALF', 'ALFUW', 'ALG', 'ALGM', 'ALGN', 'ALGS', 'ALGT', 'ALHC', 'ALIT', 'ALK', 'ALKS', 'ALKT', 'ALL', 'ALLE', 'ALLK', 'ALLO', 'ALLR', 'ALLT', 'ALLY', 'ALLpB', 'ALLpH', 'ALLpI', 'ALLpJ', 'ALMS', 'ALNT', 'ALNY', 'ALOT', 'ALRM', 'ALRN', 'ALRS', 'ALSA', 'ALSAW', 'ALSN', 'ALT', 'ALTG', 'ALTGpA', 'ALTI', 'ALTL', 'ALTM', 'ALTO', 'ALTR', 'ALTS', 'ALTY', 'ALUR', 'ALUR.WS', 'ALV', 'ALVO', 'ALVR', 'ALX', 'ALXO', 'ALZN', 'AM', 'AMAL', 'AMAT', 'AMAX', 'AMBA', 'AMBC', 'AMBI', 'AMBI.WS', 'AMBO', 'AMBP', 'AMBP.WS', 'AMC', 'AMCR', 'AMCX', 'AMD', 'AMDL', 'AMDS', 'AMDY', 'AME', 'AMED', 'AMG', 'AMGN', 'AMH', 'AMHpG', 'AMHpH', 'AMID', 'AMIX', 'AMJB', 'AMKR', 'AMLI', 'AMLP', 'AMLX', 'AMN', 'AMNA', 'AMND', 'AMOM', 'AMP', 'AMPD', 'AMPG', 'AMPGW', 'AMPH', 'AMPL', 'AMPS', 'AMPX', 'AMPX.WS', 'AMPY', 'AMR', 'AMRC', 'AMRK', 'AMRN', 'AMRX', 'AMS', 'AMSC', 'AMSF', 'AMST', 'AMT', 'AMTB', 'AMTD', 'AMTM', 'AMTR', 'AMTX', 'AMUB', 'AMWD', 'AMWL', 'AMX', 'AMZA', 'AMZD', 'AMZN', 'AMZP', 'AMZU', 'AMZY', 'AMZZ', 'AN', 'ANAB', 'ANDE', 'ANEB', 'ANET', 'ANF', 'ANGH', 'ANGHW', 'ANGI', 'ANGL', 'ANGO', 'ANGpA', 'ANGpB', 'ANIK', 'ANIP', 'ANIX', 'ANL', 'ANNX', 'ANRO', 'ANSC', 'ANSCW', 'ANSS', 'ANTE', 'ANTX', 'ANVS', 'ANY', 'AOA', 'AOCT', 'AOD', 'AOHY', 'AOK', 'AOM', 'AOMN', 'AOMR', 'AON', 'AOR', 'AORT', 'AOS', 'AOSL', 'AOTG', 'AOUT', 'AP', 'AP.WS', 'APA', 'APAM', 'APCB', 'APCX', 'APCXW', 'APD', 'APDN', 'APEI', 'APG', 'APGE ...
# Apple Silicon MPS available
#
# Processing files:
#
# Processing 2024-11-08.csv:
#   Total rows: 1623969
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 if __name__ == "__main__":
# ----> 2     train_and_visualize()
#
# Cell In[12], line 4, in train_and_visualize()
#       1 def train_and_visualize():
#       2     # Setup
#       3     config = setup_config()
# ----> 4     exp = Exp_Stock_Forecast(config)
#       5     setting = 'jupyter_test_stock_prediction'
#       6     visualizer = StockVisualizer()
#
# File ~/dev/mscAI/CS5004/myTransformer/exp_stock_forecasting.py:29, in Exp_Stock_Forecast.__init__(self, args)
#      26 self.visualizer = StockVisualizer(save_dir=args.figures_dir)
#      28 # Create data loaders
# ---> 29 self.train_loader, self.test_loader = create_data_loaders(args)
#
# File ~/dev/mscAI/CS5004/myTransformer/data_provider/data_loader.py:135, in create_data_loaders(config)
#     133 def create_data_loaders(config):
#     134     """Create train/val/test data loaders"""
# --> 135     train_dataset = StockDataset(
#     136         config.train_files,
#     137         config.seq_len,
#     138         config.pred_len,
#     139         label_len=config.label_len,
#     140         stocks=config.stocks,
#     141         features=config.features
#     142     )
#     144     test_dataset = StockDataset(
#     145         config.test_files,
#     146         config.seq_len,
#    (...)
#     150         features=config.features
#     151     )
#     153     train_loader = DataLoader(
#     154         train_dataset,
#     155         batch_size=config.batch_size,
#     156         shuffle=True,
#     157         num_workers=0  # Keep single process for now
#     158     )
#
# File ~/dev/mscAI/CS5004/myTransformer/data_provider/data_loader.py:45, in StockDataset.__init__(self, data_paths, seq_len, pred_len, label_len, stocks, features)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/dev/mscAI/CS5004/lib/python3.12/site-packages/pandas/core/series.py:2407, in Series.unique(self)
#    2344 def unique(self) -> ArrayLike:  # pylint: disable=useless-parent-delegation
#    2345     """
#    2346     Return unique values of Series object.
#    2347
#    (...)
#    2405     Categories (3, object): ['a' < 'b' < 'c']
#    2406     """
# -> 2407     return super().unique()
#
# File ~/dev/mscAI/CS5004/lib/python3.12/site-packages/pandas/core/base.py:1025, in IndexOpsMixin.unique(self)
#    1023     result = values.unique()
#    1024 else:
# -> 1025     result = algorithms.unique1d(values)
#    1026 return result
#
# File ~/dev/mscAI/CS5004/lib/python3.12/site-packages/pandas/core/algorithms.py:401, in unique(values)
#     307 def unique(values):
#     308     """
#     309     Return unique values based on a hash table.
#     310
#    (...)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#
# File ~/dev/mscAI/CS5004/lib/python3.12/site-packages/pandas/core/algorithms.py:440, in unique_with_mask(values, mask)
#     438 table = hashtable(len(values))
#     439 if mask is None:
# --> 440     uniques = table.unique(values)
#     441     uniques = _reconstruct_data(uniques, original.dtype, original)
#     442     return uniques
#
# KeyboardInterrupt:
